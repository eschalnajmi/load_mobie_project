# %%
import os
import mobie
import bioio_tifffile
import imageio
import shutil

from bioio.writers import OmeTiffWriter
from bioio import BioImage

# %%
class Project:
    def __init__(self, unit="nanometer"):
        self.project_folder = "test_project/data"
        self.dataset_name = "dataset1"
        self.dataset_folder = os.path.join(self.project_folder, self.dataset_name)
        self.target = "local"
        self.max_jobs = 1
        self.unit = unit

        self.source_list = []

    def splitchannels(self,img,path):
        num_channels = len(img.channel_names)
        all = []
        allnames = []
        fname = os.path.basename(path).split(".")[0]

        print(f"Converting {path} to {num_channels} single channel image(s): ")
        for i in range(num_channels):
            if os.path.isfile(f"data/tmp_{fname}_C{i+1}.tif"):
                print(f"\tConverted channel {img.channel_names[i]} :D")
                all.append(f"data/tmp_{fname}_C{i+1}.tif")
                allnames.append(f"{i}_{fname}")
                continue

            try:
                tempimg = img.get_image_data("TCZYX",C=i)
                print(f"\tConverted channel {img.channel_names[i]} :D")
                OmeTiffWriter.save(tempimg, f"data/tmp_{fname}_C{i+1}.tif")
                all.append(f"data/tmp_{fname}_C{i+1}.tif")
                allnames.append(f"{i}_{fname}")
            except:
                print(f"Could not convert channel {img.channel_names[i]} :(")

        return all, allnames
    
    def checkchannels(self, path):
        img = BioImage(path, reader=bioio_tifffile.Reader)
        self.dimensions = 0

        for i in img.shape:
            if i > 1:
                self.dimensions += 1

        if len(img.channel_names) > 1:
            return self.splitchannels(img, path)
       
        print(f"Only one channel found in {path} - no conversion needed :)")
        return [path], [os.path.basename(path)]
        
    def addimg(self, input_path, im_name, menu_name, color=None):
        resolution = (10., 10., 10.)

        project_folder = self.project_folder
        dataset_name = self.dataset_name
        target = self.target
        max_jobs = self.max_jobs
        unit = self.unit

        chunks = (64,64,64)
        scale_factors = 4 * [[1, 2, 2]]

        # TO-DO: check nD dimensions
        if self.dimensions == 2:
            print("2D image")
            chunks = (512,512)
            scale_factors = 4 * [[1, 2]]

        view = mobie.metadata.get_default_view("image", im_name)

        if color is not None:
            view = mobie.metadata.get_default_view("image", im_name, color=color)

        try:
            mobie.add_image(
                input_path=input_path,
                input_key='',
                root=project_folder,
                dataset_name=dataset_name,
                image_name=im_name,
                menu_name=menu_name,
                resolution=resolution,
                chunks=chunks,
                scale_factors=scale_factors,
                is_default_dataset=False,
                target=target,
                max_jobs=max_jobs,
                unit=unit,
                view=view 
            )
        except:
            print(f"Could not add {im_name} to project :(")
        
    def addimgtransform(self,input_path, im_name, menu_name, transform, color=None):
        resolution = (10, 10, 10)
        if len(transform) != 12:
            print("Invalid transformation matrix, must be 12 elements long - your matrix has", len(transform))
            return
        
        chunks = (32, 128, 128)
        scale_factors = 4 * [[1, 2, 2]]
        
        # TO-DO: check nD dimensions
        if self.dimensions == 2:
            chunks = (512,512)
            scale_factors = 4 * [[1, 2]]
        

        im = imageio.volread(input_path)
        min_val, max_val = im.min(), im.max()
        view = mobie.metadata.get_default_view(
            "image", im_name,
            source_transform={"parameters": transform},
            contrastLimits=[min_val, max_val],
        )

        if color is not None:
            view = mobie.metadata.get_default_view(
                "image", im_name,
                source_transform={"parameters": transform},
                contrastLimits=[min_val, max_val],
                color=color
            )

        try:
            mobie.add_image(
                input_path=input_path,
                input_key='',
                root=self.project_folder,
                dataset_name=self.dataset_name,
                image_name=im_name,
                menu_name=menu_name,
                resolution=resolution,
                scale_factors=scale_factors,
                transformation=transform,
                chunks=chunks,
                target=self.target,
                max_jobs=self.max_jobs,
                view=view,
                unit=self.unit,
                file_format="bdv.n5"
            )
        except:
            print(f"Could not add {im_name} to project :(")

    def add_file(self, path, menu_name, transform=None, color=None):
        input_file = path
        raw_name = os.path.basename(input_file).split(".")[0]
        menu_name = menu_name

        all, names = self.checkchannels(input_file)

        if transform:
            if len(all) == 1:
                self.addimgtransform(all[0],raw_name,menu_name, transform, color=color)
                names = [raw_name]
            else:
                for i, x in enumerate(all):
                    self.addimgtransform(x,f"{i}_{raw_name}",menu_name, transform, color=color)

            self.source_list.append(names)
            return

        if(len(all) == 1):
            self.addimg(all[0],raw_name,menu_name, color=color)
            names = [raw_name]
        else:
            for i, x in enumerate(all):
                self.addimg(x,f"{i}_{raw_name}",menu_name, color=color)

        self.source_list.append(names)

    def deletetmp(self):
        for dir in os.listdir(os.getcwd()):
            if(dir[0:3] == "tmp"):
                shutil.rmtree(dir)

        for file in os.listdir("data"):
            if(file[0:3] == "tmp"):
                os.remove(os.path.join("data",file))

# %%
project = Project(unit="nanometer")
project.add_file("data/em_20nm_z_40_145.tif", "em")
# Out:
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/luigi/parameter.py:296: UserWarning: Parameter "dtype" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# DEBUG: Checking if DownscalingWorkflow(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, target=local, dependency=DummyTask, input_path=data/em_20nm_z_40_145.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0) is complete
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/luigi/parameter.py:296: UserWarning: Parameter "scale_factor" with value "(1, 2, 2)" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# DEBUG: Checking if WriteDownscalingMetadata(tmp_folder=tmp_dataset1_em_20nm_z_40_145, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_key_prefix=, scale_offset=0, prefix=downscaling) is complete
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_em__DummyTask_None_f01a3395a1   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s3, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=/, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____ome_zarr_784397d098   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s2, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=/, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___d657c21b11   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s1, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=/, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___d82adb898c   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s0, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=/, dependency=CopyVolumeLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___7fa9471af6   has status   PENDING
# DEBUG: Checking if CopyVolumeLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=data/em_20nm_z_40_145.tif, input_key=, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=/, dependency=DummyTask) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__CopyVolumeLocal___452731ba01   has status   PENDING
# DEBUG: Checking if DummyTask() is complete
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_em__DummyTask___07bedbbf06   has status   PENDING
# INFO: Informed scheduler that task   DummyTask__99914b932b   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 7
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   CopyVolumeLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=data/em_20nm_z_40_145.tif, input_key=, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=/, dependency=DummyTask)
# Only one channel found in data/em_20nm_z_40_145.tif - no conversion needed :)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      CopyVolumeLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=data/em_20nm_z_40_145.tif, input_key=, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=/, dependency=DummyTask)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_em__DummyTask___07bedbbf06   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 6
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s0, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=/, dependency=CopyVolumeLocal)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s0, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=/, dependency=CopyVolumeLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__CopyVolumeLocal___452731ba01   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s1, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=/, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s1, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=/, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___7fa9471af6   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s2, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=/, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s2, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=/, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___d82adb898c   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s3, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=/, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, input_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, input_key=s3, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key=s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=/, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_em__DownscalingLocal___d657c21b11   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   WriteDownscalingMetadata(tmp_folder=tmp_dataset1_em_20nm_z_40_145, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      WriteDownscalingMetadata(tmp_folder=tmp_dataset1_em_20nm_z_40_145, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____ome_zarr_784397d098   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingWorkflow(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, target=local, dependency=DummyTask, input_path=data/em_20nm_z_40_145.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# INFO: [pid 39587] Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingWorkflow(tmp_folder=tmp_dataset1_em_20nm_z_40_145, max_jobs=1, config_dir=tmp_dataset1_em_20nm_z_40_145/configs, target=local, dependency=DummyTask, input_path=data/em_20nm_z_40_145.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=ome.zarr, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "em_20nm_z_40_145"}, output_path=test_project/data/dataset1/images/ome-zarr/em_20nm_z_40_145.ome.zarr, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_em__DummyTask_None_f01a3395a1   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=3678137320, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 8 tasks of which:
# * 1 complete ones were encountered:
#     - 1 DummyTask()
# * 7 ran successfully:
#     - 1 CopyVolumeLocal(...)
#     - 4 DownscalingLocal(...)
#     - 1 DownscalingWorkflow(...)
#     - 1 WriteDownscalingMetadata(...)
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====

# %%
transformation = [1.8369913620359506,
                -0.5565781005969193,
                -24.28254860249842,
                68.37265958995685,
                -0.08026654420496038,
                1.8421093883743114,
                2.937347223020879,
                -137.17914808990668,
                -6.591949208711867E-17,
                2.5724757460004824E-33,
                0.999999999999993,
                7.638334409421077E-14]
project.add_file("data/EM04468_2_63x_pos8T_LM_raw.tif", "lm", transform=transformation, color="green")
# Out:
# Converting data/EM04468_2_63x_pos8T_LM_raw.tif to 4 single channel image(s):
# 	Converted channel Channel:0:0 :D
# 	Converted channel Channel:0:1 :D
# 	Converted channel Channel:0:2 :D
# 	Converted channel Channel:0:3 :D
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/luigi/parameter.py:296: UserWarning: Parameter "dtype" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# DEBUG: Checking if DownscalingWorkflow(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0) is complete
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/luigi/parameter.py:296: UserWarning: Parameter "dimension_separator" with value "None" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/luigi/parameter.py:296: UserWarning: Parameter "scale_factor" with value "(1, 2, 2)" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# DEBUG: Checking if WriteDownscalingMetadata(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling) is complete
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_0_E_DummyTask_None_e5ff5ff2f8   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_400b66b58e   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_f73319f187   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_4a717e9cf3   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_834117c0be   has status   PENDING
# DEBUG: Checking if CopyVolumeLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_CopyVolumeLocal_None_9c092fbf8d   has status   PENDING
# DEBUG: Checking if DummyTask() is complete
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_0_E_DummyTask_None_54067677bf   has status   PENDING
# INFO: Informed scheduler that task   DummyTask__99914b932b   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 7
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   CopyVolumeLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      CopyVolumeLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_0_E_DummyTask_None_54067677bf   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 6
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_CopyVolumeLocal_None_9c092fbf8d   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_834117c0be   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_4a717e9cf3   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_0_E_DownscalingLocal_None_f73319f187   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   WriteDownscalingMetadata(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/zarr/n5.py:128: UserWarning: Attribute dataType is a reserved N5 keyword
#   warnings.warn(f"Attribute {k} is a reserved N5 keyword", UserWarning)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      WriteDownscalingMetadata(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_400b66b58e   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingWorkflow(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# INFO: [pid 39587] Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingWorkflow(tmp_folder=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_0_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C1.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "0_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_0_E_DummyTask_None_e5ff5ff2f8   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=1043347119, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 8 tasks of which:
# * 1 complete ones were encountered:
#     - 1 DummyTask()
# * 7 ran successfully:
#     - 1 CopyVolumeLocal(...)
#     - 4 DownscalingLocal(...)
#     - 1 DownscalingWorkflow(...)
#     - 1 WriteDownscalingMetadata(...)
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
#
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/mobie/xml_utils.py:127: UserWarning: The xml file at test_project/data/dataset1/images/bdv-n5/0_EM04468_2_63x_pos8T_LM_raw.xml has the resolution [10.0, 10.0, 10.0].The corresponding transformation will be over-written,make sure to factor it in with the transformation you have specified.
#   warnings.warn(
# DEBUG: Checking if DownscalingWorkflow(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0) is complete
# DEBUG: Checking if WriteDownscalingMetadata(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling) is complete
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_1_E_DummyTask_None_fe750cf5e2   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_ca993b73d0   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_115cdff71d   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_fe05e8c0bc   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_fd7f0ad129   has status   PENDING
# DEBUG: Checking if CopyVolumeLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_CopyVolumeLocal_None_15dd9b391a   has status   PENDING
# DEBUG: Checking if DummyTask() is complete
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_1_E_DummyTask_None_806d42cbc9   has status   PENDING
# INFO: Informed scheduler that task   DummyTask__99914b932b   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 7
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   CopyVolumeLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      CopyVolumeLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_1_E_DummyTask_None_806d42cbc9   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 6
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_CopyVolumeLocal_None_15dd9b391a   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_fd7f0ad129   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_fe05e8c0bc   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_1_E_DownscalingLocal_None_115cdff71d   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   WriteDownscalingMetadata(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      WriteDownscalingMetadata(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_ca993b73d0   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingWorkflow(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# INFO: [pid 39587] Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingWorkflow(tmp_folder=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_1_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C2.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "1_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_1_E_DummyTask_None_fe750cf5e2   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=6790250126, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 8 tasks of which:
# * 1 complete ones were encountered:
#     - 1 DummyTask()
# * 7 ran successfully:
#     - 1 CopyVolumeLocal(...)
#     - 4 DownscalingLocal(...)
#     - 1 DownscalingWorkflow(...)
#     - 1 WriteDownscalingMetadata(...)
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
#
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/mobie/xml_utils.py:127: UserWarning: The xml file at test_project/data/dataset1/images/bdv-n5/1_EM04468_2_63x_pos8T_LM_raw.xml has the resolution [10.0, 10.0, 10.0].The corresponding transformation will be over-written,make sure to factor it in with the transformation you have specified.
#   warnings.warn(
# DEBUG: Checking if DownscalingWorkflow(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C3.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "2_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0) is complete
# DEBUG: Checking if WriteDownscalingMetadata(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "2_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling) is complete
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_2_E_DummyTask_None_dce2438668   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_e959c862a4   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_8353a11c16   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_8a8e6d6876   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_d3f11dd59d   has status   PENDING
# DEBUG: Checking if CopyVolumeLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C3.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_CopyVolumeLocal_None_01f490bab7   has status   PENDING
# DEBUG: Checking if DummyTask() is complete
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_2_E_DummyTask_None_5c61f9f6f5   has status   PENDING
# INFO: Informed scheduler that task   DummyTask__99914b932b   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 7
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   CopyVolumeLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C3.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      CopyVolumeLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C3.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_2_E_DummyTask_None_5c61f9f6f5   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 6
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_CopyVolumeLocal_None_01f490bab7   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_d3f11dd59d   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_8a8e6d6876   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=2686896601, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_2_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/2_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_2_E_DownscalingLocal_None_8353a11c16   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# ...
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_3_E_DummyTask_None_da7977bce1   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_0a77e62bf3   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_38db41ab98   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_3d4c0e3ae7   has status   PENDING
# DEBUG: Checking if DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_c6bc5d0ca3   has status   PENDING
# DEBUG: Checking if CopyVolumeLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C4.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask) is complete
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_CopyVolumeLocal_None_3e0c582a0a   has status   PENDING
# DEBUG: Checking if DummyTask() is complete
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_3_E_DummyTask_None_33bba569dc   has status   PENDING
# INFO: Informed scheduler that task   DummyTask__99914b932b   has status   DONE
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 7
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   CopyVolumeLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C4.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      CopyVolumeLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C4.tif, input_key=, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s0, prefix=initial_scale, dtype=None, int_to_uint=False, fit_to_roi=False, effective_scale_factor=[], dimension_separator=None, dependency=DummyTask)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   CopyVolumeLocal_tmp_dataset1_3_E_DummyTask_None_33bba569dc   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 6
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s0, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s1, scale_factor=(1, 2, 2), scale_prefix=s1, halo=[1, 2, 2], effective_scale_factor=[1, 2, 2], dimension_separator=None, dependency=CopyVolumeLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_CopyVolumeLocal_None_3e0c582a0a   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 5
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s1, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s2, scale_factor=(1, 2, 2), scale_prefix=s2, halo=[1, 2, 2], effective_scale_factor=[1, 4, 4], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_c6bc5d0ca3   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 4
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s2, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s3, scale_factor=(1, 2, 2), scale_prefix=s3, halo=[1, 2, 2], effective_scale_factor=[1, 8, 8], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_3d4c0e3ae7   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 3
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingLocal(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, input_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, input_key=setup0/timepoint0/s3, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key=setup0/timepoint0/s4, scale_factor=(1, 2, 2), scale_prefix=s4, halo=[1, 2, 2], effective_scale_factor=[1, 16, 16], dimension_separator=None, dependency=DownscalingLocal)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingLocal_tmp_dataset1_3_E_DownscalingLocal_None_38db41ab98   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 2
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   WriteDownscalingMetadata(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "3_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      WriteDownscalingMetadata(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dependency=DownscalingLocal, metadata_format=bdv.n5, metadata_dict={"resolution": [10.0, 10.0, 10.0], "unit": "nanometer", "setup_name": "3_EM04468_2_63x_pos8T_LM_raw"}, output_key_prefix=, scale_offset=0, prefix=downscaling)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   WriteDownscalingMetadata_DownscalingLocal___resolution_____bdv_n5_0a77e62bf3   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) running   DownscalingWorkflow(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C4.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "3_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# INFO: [pid 39587] Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) done      DownscalingWorkflow(tmp_folder=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw, max_jobs=1, config_dir=tmp_dataset1_3_EM04468_2_63x_pos8T_LM_raw/configs, target=local, dependency=DummyTask, input_path=data/tmp_EM04468_2_63x_pos8T_LM_raw_C4.tif, input_key=, scale_factors=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], halos=[[1, 2, 2], [1, 2, 2], [1, 2, 2], [1, 2, 2]], dtype=None, int_to_uint=False, metadata_format=bdv.n5, metadata_dict={"resolution": [10, 10, 10], "unit": "nanometer", "setup_name": "3_EM04468_2_63x_pos8T_LM_raw"}, output_path=test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.n5, output_key_prefix=, force_copy=False, skip_existing_levels=False, scale_offset=0)
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   DownscalingWorkflow_tmp_dataset1_3_E_DummyTask_None_da7977bce1   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=3998194305, workers=1, host=CH7H1X6L5F, username=najmie, pid=39587) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 8 tasks of which:
# * 1 complete ones were encountered:
#     - 1 DummyTask()
# * 7 ran successfully:
#     - 1 CopyVolumeLocal(...)
#     - 4 DownscalingLocal(...)
#     - 1 DownscalingWorkflow(...)
#     - 1 WriteDownscalingMetadata(...)
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
#
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/mobie/xml_utils.py:127: UserWarning: The xml file at test_project/data/dataset1/images/bdv-n5/3_EM04468_2_63x_pos8T_LM_raw.xml has the resolution [10.0, 10.0, 10.0].The corresponding transformation will be over-written,make sure to factor it in with the transformation you have specified.
#   warnings.warn(

# %%
settings = [{"color": "white", "contrastLimits": [0., 255.]}, {"opacity": 0.75}]

mobie.create_view(project.dataset_folder, "default",
                sources=project.source_list, display_settings=settings,
                overwrite=True)
    
project.deletetmp()
# Out:
# /Users/najmie/miniconda3/envs/testmobie2/lib/python3.11/site-packages/mobie/metadata/dataset_metadata.py:72: UserWarning: A view with name default already exists for the dataset test_project/data/dataset1
#   warnings.warn(msg)
